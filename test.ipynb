# %%
url = "https://apdvgobhhznmbeahymtn.supabase.co/storage/v1/object/public/whisper/mask1,679,284,301,2231,679,284,301,233?t=2023-03-20T03%3A54%3A10.356Z"

# %%
# !pip install opencv-python-headless
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.9/53.9 MB 15.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
# WARNING: There was an error checking the latest version of pip.

# %%
import requests
import io
from PIL import Image

response = requests.get("https://apdvgobhhznmbeahymtn.supabase.co/storage/v1/object/public/whisper/mask1,679,284,301,2231,679,284,301,233?t=2023-03-20T03%3A54%3A10.356Z")
print(response)
origin_image_bytes = response.content
# Out:
# <Response [200]>

# %%
import io
output = Image.open(io.BytesIO(origin_image_bytes))

# %%
display(output)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2400x3595>
